# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import librosa
import os
import glob
import matplotlib.pyplot as plt
from tqdm import tqdm
import random

# Configuration parameters
LATENT_DIM = 100
SR = 16000  # Sample rate from MIMII dataset
AUDIO_LENGTH = 5  # seconds (MIMII contains 5s segments)
N_FFT = 1024
HOP_LENGTH = 512
N_MELS = 128
BATCH_SIZE = 8
EPOCHS = 500
TIME_DIM = 156

def load_and_preprocess_audio(file_path, is_abnormal=False):
    """Load audio file and convert to mel spectrogram"""
    # Load audio file
    audio, _ = librosa.load(file_path, sr=SR, duration=AUDIO_LENGTH)
    
    # Normalize audio
    audio = audio / (np.max(np.abs(audio)) + 1e-8)
    
    # Apply pre-emphasis
    audio = librosa.effects.preemphasis(audio)
    
    # Pad if needed
    if len(audio) < SR * AUDIO_LENGTH:
        audio = np.pad(audio, (0, SR * AUDIO_LENGTH - len(audio)))
    elif len(audio) > SR * AUDIO_LENGTH:
        audio = audio[:SR * AUDIO_LENGTH]
    
    # Create mel spectrogram
    mel_spec = librosa.feature.melspectrogram(
        y=audio, 
        sr=SR, 
        n_fft=N_FFT, 
        hop_length=HOP_LENGTH, 
        n_mels=N_MELS,
        fmin=20,
        fmax=SR//2-1000
    )
    
    # Convert to log scale
    log_mel_spec = librosa.power_to_db(mel_spec)
    
    # Normalize to [-1, 1] range
    log_mel_spec_min = log_mel_spec.min()
    log_mel_spec_max = log_mel_spec.max()
    log_mel_spec_norm = 2 * (log_mel_spec - log_mel_spec_min) / (log_mel_spec_max - log_mel_spec_min) - 1
    
    # Add channel dimension
    log_mel_spec_norm = np.expand_dims(log_mel_spec_norm, axis=-1)
    
    # Pad to match expected shape if needed
    if log_mel_spec_norm.shape[1] < TIME_DIM:
        pad_width = ((0, 0), (0, TIME_DIM - log_mel_spec_norm.shape[1]), (0, 0))
        log_mel_spec_norm = np.pad(log_mel_spec_norm, pad_width, mode='constant')
    elif log_mel_spec_norm.shape[1] > TIME_DIM:
        log_mel_spec_norm = log_mel_spec_norm[:, :TIME_DIM, :]
    
    # Add label for condition (0 for normal, 1 for abnormal)
    condition = 1 if is_abnormal else 0
    
    return log_mel_spec_norm, condition

def process_mimii_dataset(base_dir, machine_type, machine_ids=["00", "02", "04", "06"], samples_per_id=50):
    """Process MIMII dataset files for a specific machine type"""
    specs = []
    conditions = []
    file_paths = []  # Store file paths for later reference
    
    print(f"\nProcessing {machine_type} data...")
    machine_dir = os.path.join(base_dir, f"trimmed_{machine_type}")
    
    if not os.path.exists(machine_dir):
        print(f"Error: Directory not found: {machine_dir}")
        return np.array([]), np.array([]), []
        
    # Process normal samples
    normal_base_dir = os.path.join(machine_dir, "normal")
    if os.path.exists(normal_base_dir):
        # Process each machine ID
        for machine_id in machine_ids:
            normal_id_dir = os.path.join(normal_base_dir, f"id_{machine_id}")
            if os.path.exists(normal_id_dir):
                normal_files = glob.glob(os.path.join(normal_id_dir, "*.wav"))
                
                print(f"Processing {len(normal_files)} normal files for {machine_type} id_{machine_id}")
                # Limit to samples_per_id files per ID for faster processing
                for file_path in tqdm(normal_files[:samples_per_id]):
                    try:
                        spec, condition = load_and_preprocess_audio(file_path, is_abnormal=False)
                        specs.append(spec)
                        conditions.append(condition)
                        file_paths.append(file_path)
                    except Exception as e:
                        print(f"Error processing {file_path}: {e}")
            else:
                print(f"Directory not found: {normal_id_dir}")
    else:
        print(f"Normal directory not found: {normal_base_dir}")
        
    # Process abnormal samples
    abnormal_base_dir = os.path.join(machine_dir, "abnormal")
    if os.path.exists(abnormal_base_dir):
        # Process each machine ID
        for machine_id in machine_ids:
            abnormal_id_dir = os.path.join(abnormal_base_dir, f"id_{machine_id}")
            if os.path.exists(abnormal_id_dir):
                abnormal_files = glob.glob(os.path.join(abnormal_id_dir, "*.wav"))
                
                print(f"Processing {len(abnormal_files)} abnormal files for {machine_type} id_{machine_id}")
                # Limit to samples_per_id files per ID for faster processing
                for file_path in tqdm(abnormal_files[:samples_per_id]):
                    try:
                        spec, condition = load_and_preprocess_audio(file_path, is_abnormal=True)
                        specs.append(spec)
                        conditions.append(condition)
                        file_paths.append(file_path)
                    except Exception as e:
                        print(f"Error processing {file_path}: {e}")
            else:
                print(f"Directory not found: {abnormal_id_dir}")
    else:
        print(f"Abnormal directory not found: {abnormal_base_dir}")
    
    # If no files were found, create some dummy data to avoid errors
    if len(specs) == 0:
        print("WARNING: No files were processed. Creating dummy data for debugging.")
        return np.zeros((10, N_MELS, TIME_DIM, 1)), np.zeros(10), []
    
    # Convert to numpy arrays
    specs = np.array(specs)
    conditions = np.array(conditions)
    
    print(f"Dataset shape: {specs.shape}, Conditions shape: {conditions.shape}")
    print(f"Normal samples: {np.sum(conditions == 0)}, Abnormal samples: {np.sum(conditions == 1)}")
    
    return specs, conditions, file_paths

# Save example spectrograms from real data
def save_real_data_examples(specs, conditions, output_dir, file_paths=None, num_examples=5):
    """Save examples of real data spectrograms"""
    real_examples_dir = os.path.join(output_dir, "real_data_examples")
    os.makedirs(real_examples_dir, exist_ok=True)
    
    normal_indices = np.where(conditions == 0)[0]
    abnormal_indices = np.where(conditions == 1)[0]
    
    # Sample indices
    normal_samples = np.random.choice(normal_indices, min(num_examples, len(normal_indices)), replace=False)
    abnormal_samples = np.random.choice(abnormal_indices, min(num_examples, len(abnormal_indices)), replace=False)
    
    # Save normal examples
    for i, idx in enumerate(normal_samples):
        plt.figure(figsize=(10, 6))
        plt.imshow(specs[idx, :, :, 0], aspect='auto', origin='lower', cmap='viridis')
        plt.colorbar(format='%.2f')
        file_name = f"normal_example_{i+1}"
        if file_paths:
            file_name += f"_{os.path.basename(file_paths[idx])}"
        plt.title(f"Normal Example {i+1}")
        plt.xlabel('Time Frame')
        plt.ylabel('Mel Frequency Bin')
        plt.tight_layout()
        plt.savefig(f"{real_examples_dir}/{file_name}.png", dpi=300)
        plt.close()
    
    # Save abnormal examples
    for i, idx in enumerate(abnormal_samples):
        plt.figure(figsize=(10, 6))
        plt.imshow(specs[idx, :, :, 0], aspect='auto', origin='lower', cmap='viridis')
        plt.colorbar(format='%.2f')
        file_name = f"abnormal_example_{i+1}"
        if file_paths:
            file_name += f"_{os.path.basename(file_paths[idx])}"
        plt.title(f"Abnormal Example {i+1}")
        plt.xlabel('Time Frame')
        plt.ylabel('Mel Frequency Bin')
        plt.tight_layout()
        plt.savefig(f"{real_examples_dir}/{file_name}.png", dpi=300)
        plt.close()
    
    # Create a comparison grid
    plt.figure(figsize=(15, 8))
    plt.suptitle("Real Data Examples - Normal vs Abnormal", fontsize=16)
    
    for i in range(min(num_examples, len(normal_samples), len(abnormal_samples))):
        # Normal
        plt.subplot(2, num_examples, i+1)
        plt.imshow(specs[normal_samples[i], :, :, 0], aspect='auto', origin='lower', cmap='viridis')
        plt.title(f"Normal {i+1}")
        if i == 0:
            plt.ylabel('Mel Frequency Bin')
        plt.xticks([])
        
        # Abnormal
        plt.subplot(2, num_examples, num_examples+i+1)
        plt.imshow(specs[abnormal_samples[i], :, :, 0], aspect='auto', origin='lower', cmap='viridis')
        plt.title(f"Abnormal {i+1}")
        if i == 0:
            plt.ylabel('Mel Frequency Bin')
        plt.xlabel('Time Frame')
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.88)
    plt.savefig(f"{real_examples_dir}/comparison_grid.png", dpi=300)
    plt.close()
    
    print(f"Saved {num_examples} examples of real spectrograms to {real_examples_dir}")

class ExactOutputSize(layers.Layer):
    def __init__(self, target_height, target_width, **kwargs):
        super(ExactOutputSize, self).__init__(**kwargs)
        self.target_height = target_height
        self.target_width = target_width
        
    def build(self, input_shape):
        super(ExactOutputSize, self).build(input_shape)
        
    def call(self, inputs):
        return tf.image.resize(inputs, [self.target_height, self.target_width])
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.target_height, self.target_width, input_shape[3])
        
    def get_config(self):
        config = super(ExactOutputSize, self).get_config()
        config.update({
            'target_height': self.target_height,
            'target_width': self.target_width
        })
        return config

class SelfAttention(layers.Layer):
    def __init__(self, **kwargs):
        super(SelfAttention, self).__init__(**kwargs)
        self.gamma = tf.Variable(0.0, trainable=True)
        
    def build(self, input_shape):
        channels = input_shape[-1]
        self.query_conv = layers.Conv2D(channels // 8, 1, padding='same')
        self.key_conv = layers.Conv2D(channels // 8, 1, padding='same')
        self.value_conv = layers.Conv2D(channels, 1, padding='same')
        super(SelfAttention, self).build(input_shape)
        
    def call(self, x):
        batch_size, height, width, channels = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2], tf.shape(x)[3]
        
        # Apply convolutions to get query, key, value
        query = self.query_conv(x)
        key = self.key_conv(x)
        value = self.value_conv(x)
        
        # Reshape for matrix multiplication
        query_reshaped = tf.reshape(query, [-1, height * width, channels // 8])
        key_reshaped = tf.reshape(key, [-1, height * width, channels // 8])
        value_reshaped = tf.reshape(value, [-1, height * width, channels])
        
        # Calculate attention scores
        scores = tf.matmul(query_reshaped, tf.transpose(key_reshaped, [0, 2, 1]))
        attention_weights = tf.nn.softmax(scores, axis=-1)
        
        # Apply attention
        output = tf.matmul(attention_weights, value_reshaped)
        output = tf.reshape(output, [-1, height, width, channels])
        
        # Add residual connection with learnable parameter
        return x + self.gamma * output

def build_generator(latent_dim):
    """Build generator network with conditional input"""
    # Input for latent space
    noise = layers.Input(shape=(latent_dim,), name="noise_input")
    
    # Input for conditions (normal/abnormal)
    condition = layers.Input(shape=(1,), name="condition_input")
    
    # Embed the condition
    condition_embedding = layers.Embedding(2, 64)(condition)
    condition_embedding = layers.Flatten()(condition_embedding)
    
    # Concatenate noise and condition
    combined_input = layers.Concatenate()([noise, condition_embedding])
    
    # Dense layers
    x = layers.Dense(256)(combined_input)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    
    x = layers.Dense(512)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    
    # Calculate dimensions for reshaping
    target_height = N_MELS // 8  # 16
    target_width = TIME_DIM // 16  # ~19 for TIME_DIM=313
    
    x = layers.Dense(target_height * target_width * 64)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    x = layers.Reshape((target_height, target_width, 64))(x)
    
    # Transposed convolution layers
    x = layers.Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    
    x = layers.Conv2DTranspose(32, (4, 4), strides=(2, 2), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    x = SelfAttention()(x)
    
    x = layers.Conv2DTranspose(16, (4, 4), strides=(2, 2), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    
    x = layers.Conv2DTranspose(8, (4, 4), strides=(2, 2), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    
    # Ensure exact output dimensions
    x = ExactOutputSize(N_MELS, TIME_DIM)(x)
    
    # Output layer with tanh activation
    output = layers.Conv2D(1, (3, 3), activation='tanh', padding='same')(x)
    
    # Model
    model = models.Model([noise, condition], output, name="generator")
    
    return model

def build_discriminator():
    """Build discriminator network with conditional input"""
    # Input for spectrogram
    input_spec = layers.Input(shape=(N_MELS, TIME_DIM, 1), name="spec_input")
    
    # Input for conditions
    condition = layers.Input(shape=(1,), name="condition_input")
    
    # Embedding layer for condition
    embedding_dim = N_MELS * TIME_DIM
    condition_embedding = layers.Embedding(2, embedding_dim)(condition)
    condition_embedding = layers.Reshape((N_MELS, TIME_DIM, 1))(condition_embedding)
    
    # Concatenate inputs along the channel dimension
    combined_input = layers.Concatenate(axis=-1)([input_spec, condition_embedding])
    
    # Convolutional layers
    x = layers.Conv2D(32, (5, 5), strides=(2, 2), padding='same')(combined_input)
    x = layers.LeakyReLU(alpha=0.2)(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Conv2D(256, (5, 5), strides=(2, 2), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    x = layers.Dropout(0.3)(x)
    
    # Add attention
    x = SelfAttention()(x)
    
    # Flatten and dense layers
    x = layers.Flatten()(x)
    x = layers.Dense(512)(x)
    x = layers.LeakyReLU(alpha=0.2)(x)
    x = layers.Dropout(0.3)(x)
    
    # Output layer
    output = layers.Dense(1, activation='sigmoid')(x)
    
    # Model
    model = models.Model([input_spec, condition], output, name="discriminator")
    
    return model

def build_gan(generator, discriminator):
    """Build combined GAN model"""
    # Freeze discriminator during generator training
    discriminator.trainable = False
    
    # GAN input
    noise = layers.Input(shape=(LATENT_DIM,), name="gan_noise_input")
    condition = layers.Input(shape=(1,), name="gan_condition_input")
    
    # Generator output
    generated_spec = generator([noise, condition])
    
    # Discriminator output
    validity = discriminator([generated_spec, condition])
    
    # Combined model
    model = models.Model([noise, condition], validity, name="gan")
    
    return model

def save_generated_samples(generator, epoch, machine_type, output_dir):
    """Save generated spectrograms at specific epochs"""
    # Generate noise and conditions
    noise = np.random.normal(0, 1, (2, LATENT_DIM))
    conditions = np.array([[0], [1]])  # Normal and abnormal
    
    # Generate spectrograms
    gen_specs = generator.predict([noise, conditions], verbose=0)
    
    # Save combined spectrograms as images
    plt.figure(figsize=(12, 6))
    
    plt.subplot(1, 2, 1)
    plt.imshow(gen_specs[0, :, :, 0], aspect='auto', origin='lower', cmap='viridis')
    plt.title(f"Normal {machine_type.capitalize()} - Epoch {epoch}")
    plt.colorbar(format='%.2f')
    plt.xlabel('Time Frame')
    plt.ylabel('Mel Frequency Bin')
    
    plt.subplot(1, 2, 2)
    plt.imshow(gen_specs[1, :, :, 0], aspect='auto', origin='lower', cmap='viridis')
    plt.title(f"Abnormal {machine_type.capitalize()} - Epoch {epoch}")
    plt.colorbar(format='%.2f')
    plt.xlabel('Time Frame')
    plt.ylabel('Mel Frequency Bin')
    
    plt.tight_layout()
    plt.savefig(f"{output_dir}/spectrograms_epoch_{epoch}.png", dpi=300)
    plt.close()
    
    # Save individual spectrograms
    for i, condition in enumerate(["normal", "abnormal"]):
        plt.figure(figsize=(10, 6))
        plt.imshow(gen_specs[i, :, :, 0], aspect='auto', origin='lower', cmap='viridis')
        plt.title(f"{condition.capitalize()} {machine_type.capitalize()} - Epoch {epoch}")
        plt.colorbar(format='%.2f')
        plt.xlabel('Time Frame')
        plt.ylabel('Mel Frequency Bin')
        plt.tight_layout()
        plt.savefig(f"{output_dir}/{condition}_spectrogram_epoch_{epoch}.png", dpi=300)
        plt.close()

def generate_final_spectrograms(generator, machine_type, output_dir, num_samples=200):
    """Generate and save 200 normal and abnormal spectrograms after training is complete"""
    final_dir = os.path.join(output_dir, "final_spectrograms")
    os.makedirs(final_dir, exist_ok=True)
    
    for condition_label, condition_name in enumerate(["normal", "abnormal"]):
        condition_dir = os.path.join(final_dir, condition_name)
        os.makedirs(condition_dir, exist_ok=True)
        
        print(f"Generating {num_samples} {condition_name} spectrograms...")
        for i in tqdm(range(num_samples)):
            # Generate noise with variation to ensure diverse samples
            noise = np.random.normal(0, 1, (1, LATENT_DIM))
            condition = np.array([[condition_label]])
            
            # Generate spectrogram
            gen_spec = generator.predict([noise, condition], verbose=0)
            
            # Save spectrogram as image
            plt.figure(figsize=(10, 6))
            plt.imshow(gen_spec[0, :, :, 0], aspect='auto', origin='lower', cmap='viridis')
            plt.colorbar(format='%.2f')
            plt.title(f"{condition_name.capitalize()} {machine_type.capitalize()} Spectrogram")
            plt.xlabel('Time Frame')
            plt.ylabel('Mel Frequency Bin')
            plt.tight_layout()
            plt.savefig(f"{condition_dir}/{condition_name}_spectrogram_{i+1}.png", dpi=300)
            plt.close()
    
    # Create a grid of examples (8 normal, 8 abnormal)
    grid_samples = 8
    plt.figure(figsize=(16, 12))
    plt.suptitle(f"Generated {machine_type.capitalize()} Spectrograms", fontsize=16)
    
    # Generate for grid visualization
    noise_normal = np.random.normal(0, 1, (grid_samples, LATENT_DIM))
    noise_abnormal = np.random.normal(0, 1, (grid_samples, LATENT_DIM))
    
    conditions_normal = np.zeros((grid_samples, 1))
    conditions_abnormal = np.ones((grid_samples, 1))
    
    gen_specs_normal = generator.predict([noise_normal, conditions_normal], verbose=0)
    gen_specs_abnormal = generator.predict([noise_abnormal, conditions_abnormal], verbose=0)
    
    # Plot normal samples
    for i in range(grid_samples):
        plt.subplot(2, grid_samples, i+1)
        plt.imshow(gen_specs_normal[i, :, :, 0], aspect='auto', origin='lower', cmap='viridis')
        plt.title(f"Normal {i+1}")
        plt.xticks([])
        plt.yticks([])
    
    # Plot abnormal samples
    for i in range(grid_samples):
        plt.subplot(2, grid_samples, grid_samples+i+1)
        plt.imshow(gen_specs_abnormal[i, :, :, 0], aspect='auto', origin='lower', cmap='viridis')
        plt.title(f"Abnormal {i+1}")
        plt.xticks([])
        plt.yticks([])
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.savefig(f"{final_dir}/spectrogram_grid.png", dpi=300)
    plt.close()
    
    print(f"Generated {num_samples} normal and {num_samples} abnormal spectrograms saved in '{final_dir}'")

def train_gan(generator, discriminator, gan, specs, conditions, epochs, batch_size, machine_type):
    """Train the GAN model with milestone spectrograms"""
    
    # Create folder for samples
    output_dir = f"generated_samples_{machine_type}"
    os.makedirs(output_dir, exist_ok=True)
    
    # Save training info
    with open(f"{output_dir}/training_info.txt", "w") as f:
        f.write(f"Machine Type: {machine_type}\n")
        f.write(f"Dataset Size: {specs.shape[0]} samples\n")
        f.write(f"Normal Samples: {np.sum(conditions == 0)}\n")
        f.write(f"Abnormal Samples: {np.sum(conditions == 1)}\n")
        f.write(f"Training Epochs: {epochs}\n")
        f.write(f"Batch Size: {batch_size}\n")
        f.write(f"Spectrogram Shape: {specs.shape[1:3]}\n")
    
    # Arrays to store loss values
    d_losses = []
    g_losses = []
    
    # Create EMA model for final outputs
    ema_generator = tf.keras.models.clone_model(generator)
    ema_generator.set_weights(generator.get_weights())
    
    # Milestone epochs for saving samples
    milestones = [1, 10, 100, 1000, 2000]
    
    # Training loop
    for epoch in range(epochs):
        # -----------------
        # Train Discriminator
        # -----------------
        
        # Select a balanced batch of real spectrograms
        normal_indices = np.where(conditions == 0)[0]
        abnormal_indices = np.where(conditions == 1)[0]
        
        # Handle case where we might not have enough samples of each type
        normal_count = min(batch_size // 4, len(normal_indices))
        abnormal_count = min(batch_size // 4, len(abnormal_indices))
        
        # Randomly select indices for each type
        selected_normal = np.random.choice(normal_indices, normal_count, replace=False)
        selected_abnormal = np.random.choice(abnormal_indices, abnormal_count, replace=False)
        
        # Combine and shuffle
        idx = np.concatenate([selected_normal, selected_abnormal])
        np.random.shuffle(idx)
        
        real_specs = specs[idx]
        real_conditions = conditions[idx].reshape(-1, 1)
        
        # Generate batch of fake spectrograms
        noise = np.random.normal(0, 1, (len(idx), LATENT_DIM))
        # Use matched conditions for better training
        fake_conditions = real_conditions.copy()
        
        # Generate fake spectrograms
        fake_specs = generator.predict([noise, fake_conditions], verbose=0)
        
        # Label smoothing for more stable training
        real_labels = np.ones((len(idx), 1)) * 0.9
        fake_labels = np.zeros((len(idx), 1))
        
        # Train discriminator
        d_loss_real = discriminator.train_on_batch(
            [real_specs, real_conditions], 
            real_labels
        )
        d_loss_fake = discriminator.train_on_batch(
            [fake_specs, fake_conditions], 
            fake_labels
        )
        
        # Calculate discriminator loss
        if isinstance(d_loss_real, list):
            d_loss = 0.5 * (d_loss_real[0] + d_loss_fake[0])
        else:
            d_loss = 0.5 * (d_loss_real + d_loss_fake)
        
        # -----------------
        # Train Generator
        # -----------------
        
        # Generate new batch of noise and conditions
        noise = np.random.normal(0, 1, (batch_size, LATENT_DIM))
        
        # Create balanced conditions
        random_conditions = np.zeros((batch_size, 1))
        random_conditions[batch_size//2:] = 1
        np.random.shuffle(random_conditions)
        
        # Train generator
        g_loss = gan.train_on_batch([noise, random_conditions], np.ones((batch_size, 1)))
        
        # Update EMA generator weights
        decay = 0.999
        generator_weights = generator.get_weights()
        ema_weights = ema_generator.get_weights()
        
        for i in range(len(generator_weights)):
            ema_weights[i] = decay * ema_weights[i] + (1.0 - decay) * generator_weights[i]
            
        ema_generator.set_weights(ema_weights)
        
        # Store losses
        d_losses.append(d_loss)
        g_losses.append(g_loss)
        
        # Print progress
        if (epoch + 1) % 10 == 0 or epoch == 0:
            if isinstance(d_loss, np.ndarray):
                d_loss_val = float(d_loss)
            else:
                d_loss_val = d_loss
                
            if isinstance(g_loss, np.ndarray):
                g_loss_val = float(g_loss)
            else:
                g_loss_val = g_loss
                
            print(f"[{machine_type}] Epoch {epoch+1}/{epochs} | D Loss: {d_loss_val:.4f} | G Loss: {g_loss_val:.4f}")
        
        # Save samples at specific milestones
        if (epoch + 1) in milestones:
            print(f"\nGenerating samples for epoch {epoch+1}...")
            save_generated_samples(ema_generator, epoch + 1, machine_type, output_dir)
    
    # Save final models
    generator.save(f"{machine_type}_generator.h5")
    ema_generator.save(f"{machine_type}_ema_generator.h5")
    
    # Create a final output
    print(f"\nTraining complete for {machine_type}!")
    print(f"Models saved as '{machine_type}_generator.h5' and '{machine_type}_ema_generator.h5'")
    print(f"Generated samples saved in '{output_dir}'")
    
    # Generate 200 final spectrograms 
    generate_final_spectrograms(ema_generator, machine_type, output_dir, num_samples=200)
    
    # Plot loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(d_losses, label='Discriminator')
    plt.plot(g_losses, label='Generator')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'{machine_type.capitalize()} GAN Training Loss')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'{output_dir}/loss_curves.png')
    
    # Save loss values to CSV
    import pandas as pd
    df = pd.DataFrame({
        'epoch': range(1, len(d_losses) + 1),
        'discriminator_loss': d_losses,
        'generator_loss': g_losses
    })
    df.to_csv(f'{output_dir}/loss_values.csv', index=False)
    
    return d_losses, g_losses

def run_gan_training(machine_type, data_dir, epochs=None, batch_size=None, samples_per_id=50):
    """Run GAN training for a specific machine type"""
    
    # Use global parameters if not specified
    if epochs is None:
        epochs = EPOCHS
    if batch_size is None:
        batch_size = BATCH_SIZE
        
    # Print configuration
    print(f"\n=== Training Configuration ===")
    print(f"Machine Type: {machine_type}")
    print(f"Data Directory: {data_dir}")
    print(f"Epochs: {epochs}")
    print(f"Batch Size: {batch_size}")
    print("============================\n")
    
    # Process data
    specs, conditions, file_paths = process_mimii_dataset(
        data_dir, 
        machine_type, 
        machine_ids=["00", "02", "04", "06"], 
        samples_per_id=samples_per_id
    )
    
    # Check if we have enough data
    if len(specs) == 0:
        print(f"Error: No data found for machine type {machine_type}")
        return None, None, None
    
    # Save examples of real data spectrograms
    output_dir = f"generated_samples_{machine_type}"
    os.makedirs(output_dir, exist_ok=True)
    save_real_data_examples(specs, conditions, output_dir, file_paths)
    
    # Data analysis
    print("\nData Analysis:")
    normal_specs = specs[conditions == 0]
    abnormal_specs = specs[conditions == 1]
    
    print(f"Normal samples: {len(normal_specs)}")
    print(f"Abnormal samples: {len(abnormal_specs)}")
    
    # Calculate mean and std
    normal_mean = np.mean(normal_specs)
    normal_std = np.std(normal_specs)
    abnormal_mean = np.mean(abnormal_specs)
    abnormal_std = np.std(abnormal_specs)
    
    print(f"Normal mean: {normal_mean:.4f}, std: {normal_std:.4f}")
    print(f"Abnormal mean: {abnormal_mean:.4f}, std: {abnormal_std:.4f}")
    
    # Build models
    generator = build_generator(LATENT_DIM)
    discriminator = build_discriminator()
    
    # Print model summaries
    print("\nGenerator Summary:")
    generator.summary()
    print("\nDiscriminator Summary:")
    discriminator.summary()
    
    # Build GAN
    gan = build_gan(generator, discriminator)
    
    # Compile models
    discriminator.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.5),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    
    gan.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.5),
        loss='binary_crossentropy'
    )
    
    # Train the GAN
    try:
        d_losses, g_losses = train_gan(generator, discriminator, gan, specs, conditions, epochs, batch_size, machine_type)
        print(f"Training complete!")
        return generator, discriminator, (d_losses, g_losses)
        
    except Exception as e:
        print(f"Error during training: {str(e)}")
        import traceback
        traceback.print_exc()
        return None, None, None

# Jupyter notebook execution function
def run_in_notebook(data_dir, machine_type, epochs=EPOCHS, batch_size=BATCH_SIZE, samples_per_id=50):
    """
    Function to run the GAN training in a Jupyter notebook environment
    
    Parameters:
    -----------
    data_dir : str
        Directory containing MIMII dataset
    machine_type : str
        Type of machine to process ('fan', 'pump', 'slider', or 'valve')
    epochs : int
        Number of training epochs
    batch_size : int
        Batch size for training
    samples_per_id : int
        Number of samples to use per machine ID
        
    Returns:
    --------
    tuple
        (generator, discriminator, losses)
    """
    # Validate machine type
    if machine_type not in ['fan', 'pump', 'slider', 'valve']:
        print(f"Invalid machine type: {machine_type}. Must be one of: fan, pump, slider, valve")
        return None, None, None
    
    # Display settings
    print(f"Training settings:")
    print(f"  Data directory: {data_dir}")
    print(f"  Machine type: {machine_type}")
    print(f"  Epochs: {epochs}")
    print(f"  Batch size: {batch_size}")
    print(f"  Samples per ID: {samples_per_id}")
    
    # Run training
    generator, discriminator, losses = run_gan_training(
        machine_type,
        data_dir,
        epochs=epochs,
        batch_size=batch_size,
        samples_per_id=samples_per_id
    )
    
    if generator is not None:
        print(f"Training successful. Model saved as '{machine_type}_generator.h5'")
        
        # Display generated samples in the notebook
        output_dir = f"generated_samples_{machine_type}"
        
        # Display a loss curve inline
        import matplotlib.pyplot as plt
        fig, ax = plt.subplots(1, 1, figsize=(10, 5))
        if losses:
            d_losses, g_losses = losses
            ax.plot(d_losses, label='Discriminator')
            ax.plot(g_losses, label='Generator')
            ax.set_xlabel('Epoch')
            ax.set_ylabel('Loss')
            ax.set_title(f'{machine_type.capitalize()} GAN Training Loss')
            ax.grid(True, linestyle='--', alpha=0.7)
            ax.legend()
            plt.tight_layout()
            plt.show()
        
        # Display example spectrograms
        try:
            # Show final grid
            grid_path = f"{output_dir}/final_spectrograms/spectrogram_grid.png"
            if os.path.exists(grid_path):
                plt.figure(figsize=(12, 8))
                img = plt.imread(grid_path)
                plt.imshow(img)
                plt.axis('off')
                plt.tight_layout()
                plt.show()
        except Exception as e:
            print(f"Could not display example images: {e}")
            
        return generator, discriminator, losses
    else:
        print("Training failed.")
        return None, None, None

# For backward compatibility or use in scripts
def main():
    data_dir = "C:/Users/julia/DS4440/machine-noise-generator/data"
    machine_type = "fan"  
    # Run training using the notebook function
    generator, discriminator, losses = run_in_notebook(
        data_dir,
        machine_type,
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        samples_per_id=30
    )

if __name__ == "__main__":
    main()
# Out:
# Training settings:
#   Data directory: C:/Users/julia/DS4440/machine-noise-generator/data
#   Machine type: fan
#   Epochs: 500
#   Batch size: 8
#   Samples per ID: 30
#
# === Training Configuration ===
# Machine Type: fan
# Data Directory: C:/Users/julia/DS4440/machine-noise-generator/data
# Epochs: 500
# Batch Size: 8
# ...
#
#
# Processing fan data...
# Processing 30 normal files for fan id_00
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 63.69it/s]
# Processing 30 normal files for fan id_02
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 72.36it/s]
# Processing 30 normal files for fan id_04
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 66.21it/s]
# Processing 30 normal files for fan id_06
# ...

# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import librosa
import soundfile as sf
import scipy.signal
from tqdm import tqdm

# Configuration parameters (match your GAN settings)
SR = 16000  # Sample rate
N_FFT = 1024
HOP_LENGTH = 512
N_MELS = 128

# Directories to process - UPDATE THESE PATHS
DIRECTORIES = [
    "generated_samples_fan/final_spectrograms/normal",
    "generated_samples_fan/final_spectrograms/abnormal"
]

def spectrogram_to_audio(spectrogram):
    """Convert a spectrogram to audio using Griffin-Lim algorithm with fixed duration"""
    # Remove extra dimensions
    spectrogram = spectrogram.squeeze()
    
    # Find where the actual data ends (ignoring padding)
    # Calculate the standard deviation across frequency bins for each time frame
    frame_stds = np.std(spectrogram, axis=0)
    
    # Find the last frame with meaningful data (non-zero std)
    active_frames = np.where(frame_stds > 0.01)[0]
    if len(active_frames) > 0:
        last_active_frame = max(active_frames) + 1
        # Crop to active frames only
        spectrogram = spectrogram[:, :last_active_frame]
    
    # Calculate expected frames for 5-second audio
    expected_frames = int((SR * 5) / HOP_LENGTH) + 1
    
    # Resize to expected number of frames to ensure 5-second duration
    from skimage.transform import resize
    spectrogram = resize(spectrogram, (N_MELS, expected_frames), anti_aliasing=True)
    
    # Convert from normalized range back to appropriate dB range
    db_spectrogram = 40 * spectrogram  # Scale from [-1, 1] to [-40, 40]
    
    # Convert from dB back to power
    S = librosa.db_to_power(db_spectrogram)
    
    # Use Griffin-Lim algorithm for phase reconstruction
    y = librosa.feature.inverse.mel_to_audio(
        S, 
        sr=SR, 
        n_fft=N_FFT, 
        hop_length=HOP_LENGTH,
        power=2.0,
        n_iter=32  # More iterations for better quality
    )
    
    # Ensure exactly 5 seconds
    target_length = 5 * SR
    if len(y) > target_length:
        y = y[:target_length]
    elif len(y) < target_length:
        y = np.pad(y, (0, target_length - len(y)))
    
    # Normalize
    y = y / (np.max(np.abs(y)) + 1e-8) * 0.9
    
    return y
    
def process_directory(directory):
    """Process all spectrogram images in a directory and convert to WAV"""
    # Find all image files
    image_files = []
    for ext in ['*.png', '*.jpg', '*.jpeg']:
        image_files.extend(glob.glob(os.path.join(directory, ext)))
    
    if not image_files:
        print(f"No image files found in {directory}")
        return
    
    print(f"Found {len(image_files)} images in {directory}")
    
    # Process each spectrogram
    for img_path in tqdm(image_files):
        # Skip if WAV already exists
        wav_path = os.path.splitext(img_path)[0] + '.wav'
        if os.path.exists(wav_path):
            continue
        
        try:
            # Load the image
            img = plt.imread(img_path)
            
            # Extract just the spectrogram part from the figure
            # Assuming the spectrogram is the main content of the image
            if img.ndim == 3:  # Color image
                # Take first channel if it's RGB/RGBA
                img = img[:, :, 0]
            
            # Figure out orientation and extract spectrogram
            # Look for the actual data region by finding non-uniform areas
            rows_std = np.std(img, axis=1)
            cols_std = np.std(img, axis=0)
            
            # Find where the actual data is (non-zero std)
            active_rows = np.where(rows_std > 0.01)[0]
            active_cols = np.where(cols_std > 0.01)[0]
            
            if len(active_rows) > 0 and len(active_cols) > 0:
                # Crop to active area
                img = img[min(active_rows):max(active_rows)+1, 
                          min(active_cols):max(active_cols)+1]
            
            # Normalize to [0, 1] if needed
            if img.max() > 1.0:
                img = img / 255.0
            
            # Convert to range [-1, 1]
            img = 2 * img - 1
            
            # Resize to expected dimensions if necessary
            if img.shape[0] != N_MELS:
                from skimage.transform import resize
                # Determine if we need to transpose
                if img.shape[0] > img.shape[1]:  # Height > Width
                    # This is likely a transposed spectrogram
                    img = img.T
                
                # Resize to match expected dimensions
                if img.shape[0] != N_MELS:
                    img = resize(img, (N_MELS, img.shape[1]), anti_aliasing=True)
            
            # Convert to audio
            audio = spectrogram_to_audio(img)
            
            # Save as WAV file
            sf.write(wav_path, audio, SR)
            
        except Exception as e:
            print(f"Error processing {img_path}: {e}")
    
    print(f"Conversion complete. WAV files saved in {directory}")

# Main execution
if __name__ == "__main__":
    for directory in DIRECTORIES:
        if os.path.isdir(directory):
            print(f"Processing directory: {directory}")
            process_directory(directory)
        else:
            print(f"Skipping {directory} - not a directory")
# Out:
# Processing directory: generated_samples_fan/final_spectrograms/normal
# Found 200 images in generated_samples_fan/final_spectrograms/normal
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [28:56<00:00,  8.68s/it]
# Conversion complete. WAV files saved in generated_samples_fan/final_spectrograms/normal
# Processing directory: generated_samples_fan/final_spectrograms/abnormal
# Found 200 images in generated_samples_fan/final_spectrograms/abnormal
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [29:22<00:00,  8.81s/it]
# Conversion complete. WAV files saved in generated_samples_fan/final_spectrograms/abnormal
