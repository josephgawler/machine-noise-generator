# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import librosa
import os
import glob
import matplotlib.pyplot as plt
import soundfile as sf
from tqdm import tqdm
import random
import argparse

# %%
LATENT_DIM = 100
SR = 16000  # Sample rate from MIMII dataset
AUDIO_LENGTH = 10  # seconds (MIMII contains 10s segments)
N_FFT = 1024
HOP_LENGTH = 512
N_MELS = 128
BATCH_SIZE = 8  # Reduced batch size
EPOCHS = 100
TIME_DIM = 313

# %%
def load_and_preprocess_audio(file_path, is_abnormal=False):
    """Load audio file and convert to mel spectrogram"""
    # Load audio file
    audio, _ = librosa.load(file_path, sr=SR, duration=AUDIO_LENGTH)
    
    # Pad if needed
    if len(audio) < SR * AUDIO_LENGTH:
        audio = np.pad(audio, (0, SR * AUDIO_LENGTH - len(audio)))
    elif len(audio) > SR * AUDIO_LENGTH:
        audio = audio[:SR * AUDIO_LENGTH]
    
    # Create mel spectrogram
    mel_spec = librosa.feature.melspectrogram(
        y=audio, 
        sr=SR, 
        n_fft=N_FFT, 
        hop_length=HOP_LENGTH, 
        n_mels=N_MELS
    )
    
    # Convert to log scale
    log_mel_spec = librosa.power_to_db(mel_spec)
    
    # Normalize
    log_mel_spec = (log_mel_spec - log_mel_spec.min()) / (log_mel_spec.max() - log_mel_spec.min())
    
    # Add channel dimension
    log_mel_spec = np.expand_dims(log_mel_spec, axis=-1)
    
    # Pad to match expected shape if needed
    if log_mel_spec.shape[1] < TIME_DIM:
        pad_width = ((0, 0), (0, TIME_DIM - log_mel_spec.shape[1]), (0, 0))
        log_mel_spec = np.pad(log_mel_spec, pad_width, mode='constant')
    elif log_mel_spec.shape[1] > TIME_DIM:
        log_mel_spec = log_mel_spec[:, :TIME_DIM, :]
    
    # Add label for condition (0 for normal, 1 for abnormal)
    condition = 1 if is_abnormal else 0
    
    return log_mel_spec, condition

def process_mimii_dataset(base_dir, machine_type, machine_ids=["00", "02", "04", "06"], samples_per_id=50):
    """Process MIMII dataset files for a specific machine type"""
    specs = []
    conditions = []
    
    print(f"\nProcessing {machine_type} data...")
    machine_dir = os.path.join(base_dir, f"trimmed_{machine_type}")
    
    if not os.path.exists(machine_dir):
        print(f"Error: Directory not found: {machine_dir}")
        return np.array([]), np.array([])
        
    # Process normal samples
    normal_base_dir = os.path.join(machine_dir, "normal")
    if os.path.exists(normal_base_dir):
        # Process each machine ID
        for machine_id in machine_ids:
            normal_id_dir = os.path.join(normal_base_dir, f"id_{machine_id}")
            if os.path.exists(normal_id_dir):
                normal_files = glob.glob(os.path.join(normal_id_dir, "*.wav"))
                
                print(f"Processing {len(normal_files)} normal files for {machine_type} id_{machine_id}")
                # Limit to samples_per_id files per ID for faster processing
                for file_path in tqdm(normal_files[:samples_per_id]):
                    try:
                        spec, condition = load_and_preprocess_audio(file_path, is_abnormal=False)
                        specs.append(spec)
                        conditions.append(condition)
                    except Exception as e:
                        print(f"Error processing {file_path}: {e}")
            else:
                print(f"Directory not found: {normal_id_dir}")
    else:
        print(f"Normal directory not found: {normal_base_dir}")
        
    # Process abnormal samples
    abnormal_base_dir = os.path.join(machine_dir, "abnormal")
    if os.path.exists(abnormal_base_dir):
        # Process each machine ID
        for machine_id in machine_ids:
            abnormal_id_dir = os.path.join(abnormal_base_dir, f"id_{machine_id}")
            if os.path.exists(abnormal_id_dir):
                abnormal_files = glob.glob(os.path.join(abnormal_id_dir, "*.wav"))
                
                print(f"Processing {len(abnormal_files)} abnormal files for {machine_type} id_{machine_id}")
                # Limit to samples_per_id files per ID for faster processing
                for file_path in tqdm(abnormal_files[:samples_per_id]):
                    try:
                        spec, condition = load_and_preprocess_audio(file_path, is_abnormal=True)
                        specs.append(spec)
                        conditions.append(condition)
                    except Exception as e:
                        print(f"Error processing {file_path}: {e}")
            else:
                print(f"Directory not found: {abnormal_id_dir}")
    else:
        print(f"Abnormal directory not found: {abnormal_base_dir}")
    
    # If no files were found, create some dummy data to avoid errors
    if len(specs) == 0:
        print("WARNING: No files were processed. Creating dummy data for debugging.")
        return np.zeros((10, N_MELS, TIME_DIM, 1)), np.zeros(10)
    
    # Convert to numpy arrays
    specs = np.array(specs)
    conditions = np.array(conditions)
    
    print(f"Dataset shape: {specs.shape}, Conditions shape: {conditions.shape}")
    print(f"Normal samples: {np.sum(conditions == 0)}, Abnormal samples: {np.sum(conditions == 1)}")
    
    return specs, conditions

# Custom Resizing Layer to ensure exact output dimensions
class ExactOutputSize(layers.Layer):
    def __init__(self, target_height, target_width, **kwargs):
        super(ExactOutputSize, self).__init__(**kwargs)
        self.target_height = target_height
        self.target_width = target_width
        
    def build(self, input_shape):
        super(ExactOutputSize, self).build(input_shape)
        
    def call(self, inputs):
        return tf.image.resize(inputs, [self.target_height, self.target_width])
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.target_height, self.target_width, input_shape[3])
        
    def get_config(self):
        config = super(ExactOutputSize, self).get_config()
        config.update({
            'target_height': self.target_height,
            'target_width': self.target_width
        })
        return config

# Generator network
def build_generator(latent_dim):
    """Build generator network with conditional input"""
    # Input for latent space
    noise = layers.Input(shape=(latent_dim,), name="noise_input")
    
    # Input for conditions (normal/abnormal)
    condition = layers.Input(shape=(1,), name="condition_input")
    
    # Embed the condition
    condition_embedding = layers.Embedding(2, 50)(condition)
    condition_embedding = layers.Flatten()(condition_embedding)
    
    # Concatenate noise and condition
    combined_input = layers.Concatenate()([noise, condition_embedding])
    
    # Dense layers
    x = layers.Dense(256)(combined_input)
    x = layers.LeakyReLU(negative_slope=0.2)(x)
    x = layers.Dense(512)(x)
    x = layers.LeakyReLU(negative_slope=0.2)(x)
    
    # Calculate dimensions for reshaping
    target_height = N_MELS // 8  # 16
    target_width = TIME_DIM // 16  # 19 for TIME_DIM=313
    
    x = layers.Dense(target_height * target_width * 64)(x)
    x = layers.LeakyReLU(negative_slope=0.2)(x)
    x = layers.Reshape((target_height, target_width, 64))(x)
    
    # Transposed convolution layers to upsample
    x = layers.Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same')(x)
    x = layers.LeakyReLU(negative_slope=0.2)(x)
    
    x = layers.Conv2DTranspose(32, (4, 4), strides=(2, 2), padding='same')(x)
    x = layers.LeakyReLU(negative_slope=0.2)(x)
    
    x = layers.Conv2DTranspose(16, (4, 4), strides=(2, 2), padding='same')(x)
    x = layers.LeakyReLU(negative_slope=0.2)(x)
    
    x = layers.Conv2DTranspose(8, (4, 4), strides=(2, 2), padding='same')(x)
    x = layers.LeakyReLU(negative_slope=0.2)(x)
    
    # Ensure exact output dimensions match the input data
    x = ExactOutputSize(N_MELS, TIME_DIM)(x)
    
    # Output layer
    output = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
    
    # Model
    model = models.Model([noise, condition], output, name="generator")
    
    return model

# Discriminator network
def build_discriminator():
    """Build discriminator network with conditional input"""
    # Input for spectrogram with explicit shape
    input_spec = layers.Input(shape=(N_MELS, TIME_DIM, 1), name="spec_input")
    
    # Input for conditions (normal/abnormal)
    condition = layers.Input(shape=(1,), name="condition_input")
    
    # Embedding layer for condition - reshape to match input spec dimensions
    embedding_dim = N_MELS * TIME_DIM
    condition_embedding = layers.Embedding(2, embedding_dim)(condition)
    condition_embedding = layers.Reshape((N_MELS, TIME_DIM, 1))(condition_embedding)
    
    # Concatenate inputs along the channel dimension
    combined_input = layers.Concatenate(axis=-1)([input_spec, condition_embedding])
    
    # Convolutional layers with explicit padding='same' to maintain dimensions
    x = layers.Conv2D(32, (3, 3), strides=(2, 2), padding='same')(combined_input)
    x = layers.LeakyReLU(negative_slope=0.2)(x)
    x = layers.Dropout(0.25)(x)
    
    x = layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)
    x = layers.LeakyReLU(negative_slope=0.2)(x)
    x = layers.Dropout(0.25)(x)
    
    x = layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)
    x = layers.LeakyReLU(negative_slope=0.2)(x)
    x = layers.Dropout(0.25)(x)
    
    x = layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)
    x = layers.LeakyReLU(negative_slope=0.2)(x)
    x = layers.Dropout(0.25)(x)
    
    # Flatten and dense layers
    x = layers.Flatten()(x)
    x = layers.Dense(512)(x)
    x = layers.LeakyReLU(negative_slope=0.2)(x)
    
    # Output layer
    output = layers.Dense(1, activation='sigmoid')(x)
    
    # Model
    model = models.Model([input_spec, condition], output, name="discriminator")
    
    return model

# GAN model
def build_gan(generator, discriminator):
    """Build combined GAN model"""
    # Freeze discriminator during generator training
    discriminator.trainable = False
    
    # GAN input
    noise = layers.Input(shape=(LATENT_DIM,), name="gan_noise_input")
    condition = layers.Input(shape=(1,), name="gan_condition_input")
    
    # Generator output
    generated_spec = generator([noise, condition])
    
    # Discriminator output
    validity = discriminator([generated_spec, condition])
    
    # Combined model
    model = models.Model([noise, condition], validity, name="gan")
    
    return model

# Function to convert spectrogram back to audio
def spectrogram_to_audio(spectrogram):
    """Convert a generated spectrogram back to audio"""
    # Remove extra dimensions and denormalize
    spectrogram = spectrogram.squeeze()
    
    # Convert from dB back to power
    S = librosa.db_to_power(spectrogram * 80 - 80)  # Rough denormalization
    
    # Mel spectrogram to audio using Griffin-Lim algorithm
    y = librosa.feature.inverse.mel_to_audio(
        S, 
        sr=SR, 
        n_fft=N_FFT, 
        hop_length=HOP_LENGTH,
        power=2.0
    )
    
    return y

# Training functions
def train_gan(generator, discriminator, gan, specs, conditions, epochs, batch_size, machine_type, save_interval=50):
    """Train the GAN model"""
    
    # Create folder for samples for this machine type
    output_dir = f"generated_samples_{machine_type}"
    os.makedirs(output_dir, exist_ok=True)
    
    # Save a summary file with configuration details
    with open(f"{output_dir}/training_info.txt", "w") as f:
        f.write(f"Machine Type: {machine_type}\n")
        f.write(f"Dataset Size: {specs.shape[0]} samples\n")
        f.write(f"Normal Samples: {np.sum(conditions == 0)}\n")
        f.write(f"Abnormal Samples: {np.sum(conditions == 1)}\n")
        f.write(f"Training Epochs: {epochs}\n")
        f.write(f"Batch Size: {batch_size}\n")
        f.write(f"Sample Rate: {SR}\n")
        f.write(f"Audio Length: {AUDIO_LENGTH}s\n")
        f.write(f"Latent Dimension: {LATENT_DIM}\n")
    
    # Get the number of total examples
    half_batch = batch_size // 2
    
    # Arrays to store loss values
    d_losses = []
    g_losses = []
    
    # Training loop
    for epoch in range(epochs):
        # -----------------
        # Train Discriminator
        # -----------------
        
        # Select random batch of real spectrograms
        idx = np.random.randint(0, specs.shape[0], half_batch)
        real_specs = specs[idx]
        real_conditions = conditions[idx].reshape(-1, 1)
        
        # Generate batch of fake spectrograms
        noise = np.random.normal(0, 1, (half_batch, LATENT_DIM))
        fake_conditions = np.random.randint(0, 2, (half_batch, 1))
        
        # Generate fake spectrograms
        fake_specs = generator.predict([noise, fake_conditions])
        
        # Train discriminator
        d_loss_real = discriminator.train_on_batch(
            [real_specs, real_conditions], 
            np.ones((half_batch, 1))
        )
        d_loss_fake = discriminator.train_on_batch(
            [fake_specs, fake_conditions], 
            np.zeros((half_batch, 1))
        )
        
        # Calculate discriminator loss (taking mean of real and fake losses)
        if isinstance(d_loss_real, list):
            d_loss = 0.5 * (d_loss_real[0] + d_loss_fake[0])
        else:
            d_loss = 0.5 * (d_loss_real + d_loss_fake)
        
        # -----------------
        # Train Generator
        # -----------------
        
        # Generate new batch of noise and conditions
        noise = np.random.normal(0, 1, (batch_size, LATENT_DIM))
        random_conditions = np.random.randint(0, 2, (batch_size, 1))
        
        # Train generator (via the GAN model, where discriminator weights are frozen)
        g_loss = gan.train_on_batch([noise, random_conditions], np.ones((batch_size, 1)))
        
        # Store losses
        d_losses.append(d_loss)
        g_losses.append(g_loss)
        
        # Print progress - use string formatting carefully to avoid numpy format error
        if isinstance(d_loss, np.ndarray):
            d_loss_val = float(d_loss)
        else:
            d_loss_val = d_loss
            
        if isinstance(g_loss, np.ndarray):
            g_loss_val = float(g_loss)
        else:
            g_loss_val = g_loss
            
        print(f"[{machine_type}] Epoch {epoch+1}/{epochs} | D Loss: {d_loss_val:.4f} | G Loss: {g_loss_val:.4f}")
        
        # Save generated samples
        if (epoch + 1) % save_interval == 0:
            save_generated_samples(generator, epoch + 1, machine_type, output_dir)
            
        # Always save samples for the last epoch
        if epoch + 1 == epochs:
            save_generated_samples(generator, epoch + 1, machine_type, output_dir)
    
    # Save final model
    generator.save(f"{machine_type}_generator.h5")
    discriminator.save(f"{machine_type}_discriminator.h5")
    
    # Create a final output showcasing results
    print(f"\nTraining complete for {machine_type}!")
    print(f"Models saved as '{machine_type}_generator.h5' and '{machine_type}_discriminator.h5'")
    print(f"Generated samples saved in '{output_dir}'")
    print(f"Loss curves saved as '{output_dir}/loss_curves.png'")
    
    # Generate final examples (5 normal, 5 abnormal) with the trained model
    print("\nGenerating final examples...")
    final_dir = os.path.join(output_dir, "final_samples")
    os.makedirs(final_dir, exist_ok=True)
    
    for condition_label, condition_name in enumerate(["normal", "abnormal"]):
        for i in range(5):
            # Generate noise
            noise = np.random.normal(0, 1, (1, LATENT_DIM))
            condition = np.array([[condition_label]])
            
            # Generate spectrogram
            gen_spec = generator.predict([noise, condition])
            
            # Save spectrogram as image
            plt.figure(figsize=(8, 6))
            plt.imshow(gen_spec[0, :, :, 0])
            plt.title(f"{condition_name.capitalize()} {machine_type.capitalize()} Sound")
            plt.colorbar()
            plt.tight_layout()
            plt.savefig(f"{final_dir}/{condition_name}_sample_{i+1}.png")
            plt.close()
            
            # Convert to audio and save
            audio = spectrogram_to_audio(gen_spec[0])
            sf.write(f"{final_dir}/{condition_name}_sample_{i+1}.wav", audio, SR)
    
    print(f"Final samples saved in '{final_dir}'")
    
    # Create a summary report with example spectrograms
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    fig.suptitle(f'{machine_type.capitalize()} GAN Results', fontsize=16)
    
    # Plot loss curve
    axes[0, 0].plot(d_losses, label='Discriminator')
    axes[0, 0].plot(g_losses, label='Generator')
    axes[0, 0].set_xlabel('Epoch')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].set_title('Training Loss')
    axes[0, 0].legend()
    axes[0, 0].grid(True, linestyle='--', alpha=0.7)
    
    # Get 2 normal and 2 abnormal examples
    normal_specs = []
    abnormal_specs = []
    
    # Generate 2 examples of each
    for _ in range(2):
        # Normal
        noise = np.random.normal(0, 1, (1, LATENT_DIM))
        normal_spec = generator.predict([noise, np.array([[0]])])
        normal_specs.append(normal_spec[0])
        
        # Abnormal
        noise = np.random.normal(0, 1, (1, LATENT_DIM))
        abnormal_spec = generator.predict([noise, np.array([[1]])])
        abnormal_specs.append(abnormal_spec[0])
    
    # Plot normal examples
    axes[0, 1].imshow(normal_specs[0][:, :, 0])
    axes[0, 1].set_title('Normal Example 1')
    axes[0, 2].imshow(normal_specs[1][:, :, 0])
    axes[0, 2].set_title('Normal Example 2')
    
    # Plot abnormal examples
    axes[1, 1].imshow(abnormal_specs[0][:, :, 0])
    axes[1, 1].set_title('Abnormal Example 1')
    axes[1, 2].imshow(abnormal_specs[1][:, :, 0])
    axes[1, 2].set_title('Abnormal Example 2')
    
    # Add dataset info
    axes[1, 0].axis('off')
    dataset_info = (
        f"Dataset Info:\n"
        f"Machine Type: {machine_type}\n"
        f"Normal Samples: {np.sum(conditions == 0)}\n"
        f"Abnormal Samples: {np.sum(conditions == 1)}\n"
        f"Training Epochs: {epochs}\n"
        f"Final D Loss: {d_loss_val:.4f}\n"
        f"Final G Loss: {g_loss_val:.4f}"
    )
    axes[1, 0].text(0.1, 0.5, dataset_info, fontsize=12, va='center')
    
    plt.tight_layout()
    plt.savefig(f"{output_dir}/summary_report.png", dpi=300)
    plt.close()
    
    # Plot loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(d_losses, label='Discriminator')
    plt.plot(g_losses, label='Generator')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'{machine_type.capitalize()} GAN Training Loss')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'{output_dir}/loss_curves.png')
    
    # Save loss values to CSV for future reference
    import pandas as pd
    df = pd.DataFrame({
        'epoch': range(1, len(d_losses) + 1),
        'discriminator_loss': d_losses,
        'generator_loss': g_losses
    })
    df.to_csv(f'{output_dir}/loss_values.csv', index=False)
    
    return d_losses, g_losses

# %%
def save_generated_samples(generator, epoch, machine_type, output_dir):
    """Save generated spectrograms and audio samples"""
    # Generate noise and conditions
    noise = np.random.normal(0, 1, (2, LATENT_DIM))
    conditions = np.array([[0], [1]])  # Normal and abnormal
    
    # Generate spectrograms
    gen_specs = generator.predict([noise, conditions])
    
    # Save combined spectrograms as images (both normal and abnormal)
    plt.figure(figsize=(10, 5))
    
    plt.subplot(1, 2, 1)
    plt.imshow(gen_specs[0, :, :, 0])
    plt.title(f"Normal {machine_type.capitalize()} Sound")
    plt.colorbar()
    
    plt.subplot(1, 2, 2)
    plt.imshow(gen_specs[1, :, :, 0])
    plt.title(f"Abnormal {machine_type.capitalize()} Sound")
    plt.colorbar()
    
    plt.tight_layout()
    plt.savefig(f"{output_dir}/spectrograms_epoch_{epoch}.png")
    plt.close()
    
    # Convert spectrograms to audio and save individual files
    for i, condition in enumerate(["normal", "abnormal"]):
        # Save individual spectrogram image
        plt.figure(figsize=(8, 6))
        plt.imshow(gen_specs[i, :, :, 0])
        plt.title(f"{condition.capitalize()} {machine_type.capitalize()} Sound (Epoch {epoch})")
        plt.colorbar()
        plt.tight_layout()
        plt.savefig(f"{output_dir}/{condition}_spectrogram_epoch_{epoch}.png")
        plt.close()
        
        # Convert to audio and save
        audio = spectrogram_to_audio(gen_specs[i])
        sf.write(f"{output_dir}/{condition}_epoch_{epoch}.wav", audio, SR)

# %%
# Set these variables instead of using command-line arguments
machine_type = "fan"  # Change this to "pump", "slider", or "valve" as needed
data_dir = r"C:\Users\julia\DS4440\machine-noise-generator\data"
samples_per_id = 50
machine_ids = ["00", "02", "04", "06"]

# Print configuration
print(f"\n=== Training Configuration ===")
print(f"Machine Type: {machine_type}")
print(f"Data Directory: {data_dir}")
print(f"Epochs: {EPOCHS}")
print(f"Batch Size: {BATCH_SIZE}")
print("============================\n")

# Process data for the specified machine type
specs, conditions = process_mimii_dataset(
    data_dir, 
    machine_type, 
    machine_ids, 
    samples_per_id
)

# Check if we have enough data
if len(specs) == 0:
    print(f"Error: No data found for machine type {machine_type}")
else:
    # Build models with explicit shapes
    generator = build_generator(LATENT_DIM)
    discriminator = build_discriminator()
    
    # Print model summaries
    print("\nGenerator Summary:")
    generator.summary()
    print("\nDiscriminator Summary:")
    discriminator.summary()
    
    # Test the generator to verify output shape
    noise = np.random.normal(0, 1, (1, LATENT_DIM))
    condition = np.array([[0]])  # Normal condition
    test_output = generator.predict([noise, condition])
    print(f"Generator test output shape: {test_output.shape}")
    
    # Test the discriminator to verify it accepts the generator's output
    disc_output = discriminator.predict([test_output, condition])
    print(f"Discriminator test output shape with generator output: {disc_output.shape}")
    
    # Build GAN
    gan = build_gan(generator, discriminator)
    
    # Compile models with lower learning rates
    discriminator.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, beta_1=0.5),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    
    gan.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005, beta_1=0.5),
        loss='binary_crossentropy'
    )
    
    # Start with short training
    short_epochs = 5
    try:
        print(f"Starting short training run for {machine_type}...")
        train_gan(generator, discriminator, gan, specs, conditions, short_epochs, BATCH_SIZE, machine_type)
        
        print(f"Short training successful! Now starting full training for {machine_type}...")
        # If short training works, continue with full training
        train_gan(generator, discriminator, gan, specs, conditions, EPOCHS, BATCH_SIZE, machine_type)
        
        print(f"Training complete!")
        
    except Exception as e:
        print(f"Error during training: {str(e)}")
        # Print detailed error info
        import traceback
        traceback.print_exc()
# Out:
# === Training Configuration ===
# Machine Type: fan
# Data Directory: C:\Users\julia\DS4440\machine-noise-generator\data
# Epochs: 100
# Batch Size: 8
# ============================
#
#
# Processing fan data...
# Processing 30 normal files for fan id_00
#   0%|                                                                                           | 0/30 [00:00<?, ?it/s]C:\Users\julia\anaconda3\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# C:\Users\julia\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# C:\Users\julia\anaconda3\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:04<00:00,  7.09it/s]
# Processing 30 normal files for fan id_02
# 100%|█████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 105.02it/s]
# Processing 30 normal files for fan id_04
# 100%|█████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 100.91it/s]
# Processing 30 normal files for fan id_06
# 100%|█████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 109.60it/s]
# Processing 30 abnormal files for fan id_00
# 100%|█████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 114.63it/s]
# Processing 30 abnormal files for fan id_02
# 100%|█████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 108.28it/s]
# Processing 30 abnormal files for fan id_04
# 100%|█████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 108.84it/s]
# Processing 30 abnormal files for fan id_06
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 93.95it/s]
# Dataset shape: (240, 128, 313, 1), Conditions shape: (240,)
# Normal samples: 120, Abnormal samples: 120
#
# Generator Summary:
# Model: "generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ condition_input (InputLayer)  │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding (Embedding)         │ (None, 1, 50)             │             100 │ condition_input[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ noise_input (InputLayer)      │ (None, 100)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 50)                │               0 │ embedding[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 150)               │               0 │ noise_input[0][0],         │
# │                               │                           │                 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 256)               │          38,656 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu (LeakyReLU)       │ (None, 256)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 512)               │         131,584 │ leaky_re_lu[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)     │ (None, 512)               │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 19456)             │       9,980,928 │ leaky_re_lu_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)     │ (None, 19456)             │               0 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape (Reshape)             │ (None, 16, 19, 64)        │               0 │ leaky_re_lu_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose              │ (None, 32, 38, 64)        │          65,600 │ reshape[0][0]              │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)     │ (None, 32, 38, 64)        │               0 │ conv2d_transpose[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_1            │ (None, 64, 76, 32)        │          32,800 │ leaky_re_lu_3[0][0]        │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)     │ (None, 64, 76, 32)        │               0 │ conv2d_transpose_1[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_2            │ (None, 128, 152, 16)      │           8,208 │ leaky_re_lu_4[0][0]        │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)     │ (None, 128, 152, 16)      │               0 │ conv2d_transpose_2[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_transpose_3            │ (None, 256, 304, 8)       │           2,056 │ leaky_re_lu_5[0][0]        │
# │ (Conv2DTranspose)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)     │ (None, 256, 304, 8)       │               0 │ conv2d_transpose_3[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ exact_output_size             │ (None, 128, 313, 8)       │               0 │ leaky_re_lu_6[0][0]        │
# │ (ExactOutputSize)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 128, 313, 1)       │              73 │ exact_output_size[0][0]    │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 10,260,005 (39.14 MB)
#  Trainable params: 10,260,005 (39.14 MB)
#  Non-trainable params: 0 (0.00 B)
# Discriminator Summary:
# Model: "discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ condition_input (InputLayer)  │ (None, 1)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding_1 (Embedding)       │ (None, 1, 40064)          │          80,128 │ condition_input[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ spec_input (InputLayer)       │ (None, 128, 313, 1)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_1 (Reshape)           │ (None, 128, 313, 1)       │               0 │ embedding_1[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_1 (Concatenate)   │ (None, 128, 313, 2)       │               0 │ spec_input[0][0],          │
# │                               │                           │                 │ reshape_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 64, 157, 32)       │             608 │ concatenate_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)     │ (None, 64, 157, 32)       │               0 │ conv2d_1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 64, 157, 32)       │               0 │ leaky_re_lu_7[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 32, 79, 64)        │          18,496 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)     │ (None, 32, 79, 64)        │               0 │ conv2d_2[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 32, 79, 64)        │               0 │ leaky_re_lu_8[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 16, 40, 128)       │          73,856 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)     │ (None, 16, 40, 128)       │               0 │ conv2d_3[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 16, 40, 128)       │               0 │ leaky_re_lu_9[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 8, 20, 256)        │         295,168 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)    │ (None, 8, 20, 256)        │               0 │ conv2d_4[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_3 (Dropout)           │ (None, 8, 20, 256)        │               0 │ leaky_re_lu_10[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_1 (Flatten)           │ (None, 40960)             │               0 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 512)               │      20,972,032 │ flatten_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)    │ (None, 512)               │               0 │ dense_3[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 1)                 │             513 │ leaky_re_lu_11[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 21,440,801 (81.79 MB)
#  Trainable params: 21,440,801 (81.79 MB)
#  Non-trainable params: 0 (0.00 B)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# Generator test output shape: (1, 128, 313, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Discriminator test output shape with generator output: (1, 1)
# Starting short training run for fan...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# C:\Users\julia\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:82: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# [fan] Epoch 1/5 | D Loss: 0.7007 | G Loss: 0.6869
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# [fan] Epoch 2/5 | D Loss: 0.6980 | G Loss: 0.6899
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# [fan] Epoch 3/5 | D Loss: 0.6965 | G Loss: 0.6856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# [fan] Epoch 4/5 | D Loss: 0.6977 | G Loss: 0.6851
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# [fan] Epoch 5/5 | D Loss: 0.6977 | G Loss: 0.6847
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training complete for fan!
# Models saved as 'fan_generator.h5' and 'fan_discriminator.h5'
# Generated samples saved in 'generated_samples_fan'
# Loss curves saved as 'generated_samples_fan/loss_curves.png'
#
# Generating final examples...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Final samples saved in 'generated_samples_fan\final_samples'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Short training successful! Now starting full training for fan...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# [fan] Epoch 1/100 | D Loss: 0.6988 | G Loss: 0.6859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# [fan] Epoch 2/100 | D Loss: 0.6991 | G Loss: 0.6856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# [fan] Epoch 3/100 | D Loss: 0.6993 | G Loss: 0.6859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# [fan] Epoch 4/100 | D Loss: 0.6994 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# [fan] Epoch 5/100 | D Loss: 0.6993 | G Loss: 0.6855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# [fan] Epoch 6/100 | D Loss: 0.6990 | G Loss: 0.6854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# [fan] Epoch 7/100 | D Loss: 0.6989 | G Loss: 0.6853
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# [fan] Epoch 8/100 | D Loss: 0.6984 | G Loss: 0.6853
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [fan] Epoch 9/100 | D Loss: 0.6984 | G Loss: 0.6851
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# [fan] Epoch 10/100 | D Loss: 0.6984 | G Loss: 0.6849
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# [fan] Epoch 11/100 | D Loss: 0.6981 | G Loss: 0.6849
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# [fan] Epoch 12/100 | D Loss: 0.6979 | G Loss: 0.6849
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# [fan] Epoch 13/100 | D Loss: 0.6977 | G Loss: 0.6850
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# [fan] Epoch 14/100 | D Loss: 0.6979 | G Loss: 0.6847
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# [fan] Epoch 15/100 | D Loss: 0.6981 | G Loss: 0.6847
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# [fan] Epoch 16/100 | D Loss: 0.6984 | G Loss: 0.6850
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# [fan] Epoch 17/100 | D Loss: 0.6983 | G Loss: 0.6851
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# [fan] Epoch 18/100 | D Loss: 0.6982 | G Loss: 0.6852
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [fan] Epoch 19/100 | D Loss: 0.6984 | G Loss: 0.6851
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# [fan] Epoch 20/100 | D Loss: 0.6984 | G Loss: 0.6853
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# [fan] Epoch 21/100 | D Loss: 0.6982 | G Loss: 0.6852
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# [fan] Epoch 22/100 | D Loss: 0.6981 | G Loss: 0.6854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# [fan] Epoch 23/100 | D Loss: 0.6981 | G Loss: 0.6855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# [fan] Epoch 24/100 | D Loss: 0.6980 | G Loss: 0.6855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# [fan] Epoch 25/100 | D Loss: 0.6978 | G Loss: 0.6855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# [fan] Epoch 26/100 | D Loss: 0.6978 | G Loss: 0.6855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# [fan] Epoch 27/100 | D Loss: 0.6976 | G Loss: 0.6856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# [fan] Epoch 28/100 | D Loss: 0.6976 | G Loss: 0.6857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# [fan] Epoch 29/100 | D Loss: 0.6976 | G Loss: 0.6856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# [fan] Epoch 30/100 | D Loss: 0.6974 | G Loss: 0.6858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# [fan] Epoch 31/100 | D Loss: 0.6973 | G Loss: 0.6858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# [fan] Epoch 32/100 | D Loss: 0.6975 | G Loss: 0.6859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# [fan] Epoch 33/100 | D Loss: 0.6977 | G Loss: 0.6859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# [fan] Epoch 34/100 | D Loss: 0.6978 | G Loss: 0.6859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# [fan] Epoch 35/100 | D Loss: 0.6979 | G Loss: 0.6859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# [fan] Epoch 36/100 | D Loss: 0.6978 | G Loss: 0.6859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# [fan] Epoch 37/100 | D Loss: 0.6978 | G Loss: 0.6858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# [fan] Epoch 38/100 | D Loss: 0.6978 | G Loss: 0.6859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# [fan] Epoch 39/100 | D Loss: 0.6978 | G Loss: 0.6857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# [fan] Epoch 40/100 | D Loss: 0.6976 | G Loss: 0.6854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# [fan] Epoch 41/100 | D Loss: 0.6976 | G Loss: 0.6855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# [fan] Epoch 42/100 | D Loss: 0.6975 | G Loss: 0.6856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# [fan] Epoch 43/100 | D Loss: 0.6974 | G Loss: 0.6855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# [fan] Epoch 44/100 | D Loss: 0.6973 | G Loss: 0.6857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# [fan] Epoch 45/100 | D Loss: 0.6973 | G Loss: 0.6858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# [fan] Epoch 46/100 | D Loss: 0.6973 | G Loss: 0.6858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# [fan] Epoch 47/100 | D Loss: 0.6974 | G Loss: 0.6859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# [fan] Epoch 48/100 | D Loss: 0.6973 | G Loss: 0.6858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# [fan] Epoch 49/100 | D Loss: 0.6973 | G Loss: 0.6858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# [fan] Epoch 50/100 | D Loss: 0.6972 | G Loss: 0.6858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# [fan] Epoch 51/100 | D Loss: 0.6971 | G Loss: 0.6857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# [fan] Epoch 52/100 | D Loss: 0.6971 | G Loss: 0.6857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# [fan] Epoch 53/100 | D Loss: 0.6973 | G Loss: 0.6859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# [fan] Epoch 54/100 | D Loss: 0.6974 | G Loss: 0.6859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# [fan] Epoch 55/100 | D Loss: 0.6975 | G Loss: 0.6858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# [fan] Epoch 56/100 | D Loss: 0.6975 | G Loss: 0.6857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# [fan] Epoch 57/100 | D Loss: 0.6974 | G Loss: 0.6858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# [fan] Epoch 58/100 | D Loss: 0.6975 | G Loss: 0.6858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# [fan] Epoch 59/100 | D Loss: 0.6975 | G Loss: 0.6859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# [fan] Epoch 60/100 | D Loss: 0.6975 | G Loss: 0.6861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# [fan] Epoch 61/100 | D Loss: 0.6975 | G Loss: 0.6861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# [fan] Epoch 62/100 | D Loss: 0.6976 | G Loss: 0.6861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# [fan] Epoch 63/100 | D Loss: 0.6975 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# [fan] Epoch 64/100 | D Loss: 0.6975 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# [fan] Epoch 65/100 | D Loss: 0.6976 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# [fan] Epoch 66/100 | D Loss: 0.6976 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# [fan] Epoch 67/100 | D Loss: 0.6976 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# [fan] Epoch 68/100 | D Loss: 0.6976 | G Loss: 0.6861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# [fan] Epoch 69/100 | D Loss: 0.6976 | G Loss: 0.6861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# [fan] Epoch 70/100 | D Loss: 0.6975 | G Loss: 0.6861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# [fan] Epoch 71/100 | D Loss: 0.6975 | G Loss: 0.6860
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# [fan] Epoch 72/100 | D Loss: 0.6975 | G Loss: 0.6861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# [fan] Epoch 73/100 | D Loss: 0.6975 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# [fan] Epoch 74/100 | D Loss: 0.6975 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# [fan] Epoch 75/100 | D Loss: 0.6976 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# [fan] Epoch 76/100 | D Loss: 0.6975 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# [fan] Epoch 77/100 | D Loss: 0.6975 | G Loss: 0.6861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# [fan] Epoch 78/100 | D Loss: 0.6975 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# [fan] Epoch 79/100 | D Loss: 0.6976 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# [fan] Epoch 80/100 | D Loss: 0.6977 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# [fan] Epoch 81/100 | D Loss: 0.6977 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# [fan] Epoch 82/100 | D Loss: 0.6978 | G Loss: 0.6863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# [fan] Epoch 83/100 | D Loss: 0.6978 | G Loss: 0.6863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# [fan] Epoch 84/100 | D Loss: 0.6978 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# [fan] Epoch 85/100 | D Loss: 0.6978 | G Loss: 0.6863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# [fan] Epoch 86/100 | D Loss: 0.6978 | G Loss: 0.6863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# [fan] Epoch 87/100 | D Loss: 0.6978 | G Loss: 0.6863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# [fan] Epoch 88/100 | D Loss: 0.6979 | G Loss: 0.6863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# [fan] Epoch 89/100 | D Loss: 0.6980 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [fan] Epoch 90/100 | D Loss: 0.6980 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# [fan] Epoch 91/100 | D Loss: 0.6980 | G Loss: 0.6863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# [fan] Epoch 92/100 | D Loss: 0.6980 | G Loss: 0.6863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# [fan] Epoch 93/100 | D Loss: 0.6980 | G Loss: 0.6862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# [fan] Epoch 94/100 | D Loss: 0.6980 | G Loss: 0.6861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# [fan] Epoch 95/100 | D Loss: 0.6980 | G Loss: 0.6860
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# [fan] Epoch 96/100 | D Loss: 0.6981 | G Loss: 0.6860
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# [fan] Epoch 97/100 | D Loss: 0.6981 | G Loss: 0.6861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# [fan] Epoch 98/100 | D Loss: 0.6982 | G Loss: 0.6860
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# [fan] Epoch 99/100 | D Loss: 0.6982 | G Loss: 0.6860
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# [fan] Epoch 100/100 | D Loss: 0.6982 | G Loss: 0.6861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training complete for fan!
# Models saved as 'fan_generator.h5' and 'fan_discriminator.h5'
# Generated samples saved in 'generated_samples_fan'
# Loss curves saved as 'generated_samples_fan/loss_curves.png'
#
# Generating final examples...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Final samples saved in 'generated_samples_fan\final_samples'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Training complete!
